# %%
# !pip3 install dvc mlflow numpy pandas scikit-learn
# Out:
# Requirement already satisfied: dvc in ./.venv/lib/python3.12/site-packages (3.64.0)
# Requirement already satisfied: mlflow in ./.venv/lib/python3.12/site-packages (3.6.0)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (2.3.5)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.12/site-packages (1.7.2)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.12/site-packages (from dvc) (25.4.0)
# Requirement already satisfied: celery in ./.venv/lib/python3.12/site-packages (from dvc) (5.5.3)
# Requirement already satisfied: colorama>=0.3.9 in ./.venv/lib/python3.12/site-packages (from dvc) (0.4.6)
# Requirement already satisfied: configobj>=5.0.9 in ./.venv/lib/python3.12/site-packages (from dvc) (5.0.9)
# Requirement already satisfied: distro>=1.3 in ./.venv/lib/python3.12/site-packages (from dvc) (1.9.0)
# Requirement already satisfied: dpath<3,>=2.1.0 in ./.venv/lib/python3.12/site-packages (from dvc) (2.2.0)
# Requirement already satisfied: dulwich in ./.venv/lib/python3.12/site-packages (from dvc) (0.24.10)
# Requirement already satisfied: dvc-data<3.17,>=3.16.2 in ./.venv/lib/python3.12/site-packages (from dvc) (3.16.12)
# Requirement already satisfied: dvc-http>=2.29.0 in ./.venv/lib/python3.12/site-packages (from dvc) (2.32.0)
# Requirement already satisfied: dvc-objects in ./.venv/lib/python3.12/site-packages (from dvc) (5.1.2)
# Requirement already satisfied: dvc-render<2,>=1.0.1 in ./.venv/lib/python3.12/site-packages (from dvc) (1.0.2)
# Requirement already satisfied: dvc-studio-client<1,>=0.21 in ./.venv/lib/python3.12/site-packages (from dvc) (0.22.0)
# Requirement already satisfied: dvc-task<1,>=0.3.0 in ./.venv/lib/python3.12/site-packages (from dvc) (0.40.2)
# Requirement already satisfied: flatten_dict<1,>=0.4.1 in ./.venv/lib/python3.12/site-packages (from dvc) (0.4.2)
# Requirement already satisfied: flufl.lock<9,>=8.1.0 in ./.venv/lib/python3.12/site-packages (from dvc) (8.2.0)
# Requirement already satisfied: fsspec>=2024.2.0 in ./.venv/lib/python3.12/site-packages (from dvc) (2025.10.0)
# Requirement already satisfied: funcy>=1.14 in ./.venv/lib/python3.12/site-packages (from dvc) (2.0)
# Requirement already satisfied: grandalf<1,>=0.7 in ./.venv/lib/python3.12/site-packages (from dvc) (0.8)
# Requirement already satisfied: gto<2,>=1.6.0 in ./.venv/lib/python3.12/site-packages (from dvc) (1.9.0)
# Requirement already satisfied: hydra-core>=1.1 in ./.venv/lib/python3.12/site-packages (from dvc) (1.3.2)
# Requirement already satisfied: iterative-telemetry>=0.0.7 in ./.venv/lib/python3.12/site-packages (from dvc) (0.0.10)
# Requirement already satisfied: kombu in ./.venv/lib/python3.12/site-packages (from dvc) (5.5.4)
# Requirement already satisfied: networkx>=2.5 in ./.venv/lib/python3.12/site-packages (from dvc) (3.6)
# Requirement already satisfied: omegaconf in ./.venv/lib/python3.12/site-packages (from dvc) (2.3.0)
# Requirement already satisfied: packaging>=19 in ./.venv/lib/python3.12/site-packages (from dvc) (25.0)
# Requirement already satisfied: pathspec>=0.10.3 in ./.venv/lib/python3.12/site-packages (from dvc) (0.12.1)
# Requirement already satisfied: platformdirs<5,>=3.1.1 in ./.venv/lib/python3.12/site-packages (from dvc) (4.5.0)
# Requirement already satisfied: psutil>=5.8 in ./.venv/lib/python3.12/site-packages (from dvc) (7.1.3)
# Requirement already satisfied: pydot>=1.2.4 in ./.venv/lib/python3.12/site-packages (from dvc) (4.0.1)
# Requirement already satisfied: pygtrie>=2.3.2 in ./.venv/lib/python3.12/site-packages (from dvc) (2.5.0)
# Requirement already satisfied: pyparsing>=2.4.7 in ./.venv/lib/python3.12/site-packages (from dvc) (3.2.5)
# Requirement already satisfied: requests>=2.22 in ./.venv/lib/python3.12/site-packages (from dvc) (2.32.5)
# Requirement already satisfied: rich>=12 in ./.venv/lib/python3.12/site-packages (from dvc) (14.2.0)
# Requirement already satisfied: ruamel.yaml>=0.17.11 in ./.venv/lib/python3.12/site-packages (from dvc) (0.18.16)
# Requirement already satisfied: scmrepo<4,>=3.5.2 in ./.venv/lib/python3.12/site-packages (from dvc) (3.5.6)
# Requirement already satisfied: shortuuid>=0.5 in ./.venv/lib/python3.12/site-packages (from dvc) (1.0.13)
# Requirement already satisfied: shtab<2,>=1.3.4 in ./.venv/lib/python3.12/site-packages (from dvc) (1.8.0)
# Requirement already satisfied: tabulate>=0.8.7 in ./.venv/lib/python3.12/site-packages (from dvc) (0.9.0)
# Requirement already satisfied: tomlkit>=0.11.1 in ./.venv/lib/python3.12/site-packages (from dvc) (0.13.3)
# Requirement already satisfied: tqdm<5,>=4.63.1 in ./.venv/lib/python3.12/site-packages (from dvc) (4.67.1)
# Requirement already satisfied: voluptuous>=0.11.7 in ./.venv/lib/python3.12/site-packages (from dvc) (0.15.2)
# Requirement already satisfied: zc.lockfile>=1.2.1 in ./.venv/lib/python3.12/site-packages (from dvc) (4.0)
# Requirement already satisfied: mlflow-skinny==3.6.0 in ./.venv/lib/python3.12/site-packages (from mlflow) (3.6.0)
# Requirement already satisfied: mlflow-tracing==3.6.0 in ./.venv/lib/python3.12/site-packages (from mlflow) (3.6.0)
# Requirement already satisfied: Flask-CORS<7 in ./.venv/lib/python3.12/site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: Flask<4 in ./.venv/lib/python3.12/site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in ./.venv/lib/python3.12/site-packages (from mlflow) (1.17.2)
# Requirement already satisfied: cryptography<47,>=43.0.0 in ./.venv/lib/python3.12/site-packages (from mlflow) (46.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in ./.venv/lib/python3.12/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in ./.venv/lib/python3.12/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in ./.venv/lib/python3.12/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: huey<3,>=2.5.0 in ./.venv/lib/python3.12/site-packages (from mlflow) (2.5.4)
# Requirement already satisfied: matplotlib<4 in ./.venv/lib/python3.12/site-packages (from mlflow) (3.10.7)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in ./.venv/lib/python3.12/site-packages (from mlflow) (22.0.0)
# Requirement already satisfied: scipy<2 in ./.venv/lib/python3.12/site-packages (from mlflow) (1.16.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in ./.venv/lib/python3.12/site-packages (from mlflow) (2.0.44)
# Requirement already satisfied: cachetools<7,>=5.0.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (6.2.2)
# Requirement already satisfied: click<9,>=7.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.73.0)
# Requirement already satisfied: fastapi<1 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.122.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.38.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.38.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (6.33.1)
# Requirement already satisfied: pydantic<3,>=2.0.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (6.0.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.38.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: Mako in ./.venv/lib/python3.12/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=2.0.0 in ./.venv/lib/python3.12/site-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in ./.venv/lib/python3.12/site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: dictdiffer>=0.8.1 in ./.venv/lib/python3.12/site-packages (from dvc-data<3.17,>=3.16.2->dvc) (0.9.0)
# Requirement already satisfied: diskcache>=5.2.1 in ./.venv/lib/python3.12/site-packages (from dvc-data<3.17,>=3.16.2->dvc) (5.6.3)
# Requirement already satisfied: sqltrie<1,>=0.11.0 in ./.venv/lib/python3.12/site-packages (from dvc-data<3.17,>=3.16.2->dvc) (0.11.2)
# Requirement already satisfied: orjson<4,>=3 in ./.venv/lib/python3.12/site-packages (from dvc-data<3.17,>=3.16.2->dvc) (3.11.4)
# Requirement already satisfied: aiohttp-retry>=2.5.0 in ./.venv/lib/python3.12/site-packages (from dvc-http>=2.29.0->dvc) (2.9.1)
# Requirement already satisfied: billiard<5.0,>=4.2.1 in ./.venv/lib/python3.12/site-packages (from celery->dvc) (4.2.4)
# Requirement already satisfied: vine<6.0,>=5.1.0 in ./.venv/lib/python3.12/site-packages (from celery->dvc) (5.1.0)
# Requirement already satisfied: click-didyoumean>=0.3.0 in ./.venv/lib/python3.12/site-packages (from celery->dvc) (0.3.1)
# Requirement already satisfied: click-repl>=0.2.0 in ./.venv/lib/python3.12/site-packages (from celery->dvc) (0.3.0)
# Requirement already satisfied: click-plugins>=1.1.1 in ./.venv/lib/python3.12/site-packages (from celery->dvc) (1.1.1.2)
# Requirement already satisfied: blinker>=1.9.0 in ./.venv/lib/python3.12/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in ./.venv/lib/python3.12/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in ./.venv/lib/python3.12/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in ./.venv/lib/python3.12/site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in ./.venv/lib/python3.12/site-packages (from Flask<4->mlflow) (3.1.4)
# Requirement already satisfied: six<2.0,>=1.12 in ./.venv/lib/python3.12/site-packages (from flatten_dict<1,>=0.4.1->dvc) (1.17.0)
# Requirement already satisfied: atpublic in ./.venv/lib/python3.12/site-packages (from flufl.lock<9,>=8.1.0->dvc) (7.0.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in ./.venv/lib/python3.12/site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in ./.venv/lib/python3.12/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: entrypoints in ./.venv/lib/python3.12/site-packages (from gto<2,>=1.6.0->dvc) (0.4)
# Requirement already satisfied: pydantic-settings>=2 in ./.venv/lib/python3.12/site-packages (from gto<2,>=1.6.0->dvc) (2.12.0)
# Requirement already satisfied: semver>=2.13.0 in ./.venv/lib/python3.12/site-packages (from gto<2,>=1.6.0->dvc) (3.0.4)
# Requirement already satisfied: typer>=0.4.1 in ./.venv/lib/python3.12/site-packages (from gto<2,>=1.6.0->dvc) (0.20.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in ./.venv/lib/python3.12/site-packages (from hydra-core>=1.1->dvc) (4.9.3)
# Requirement already satisfied: appdirs in ./.venv/lib/python3.12/site-packages (from iterative-telemetry>=0.0.7->dvc) (1.4.4)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from iterative-telemetry>=0.0.7->dvc) (3.20.0)
# Requirement already satisfied: amqp<6.0.0,>=5.1.1 in ./.venv/lib/python3.12/site-packages (from kombu->dvc) (5.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (12.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.22->dvc) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests>=2.22->dvc) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests>=2.22->dvc) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.12/site-packages (from rich>=12->dvc) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.12/site-packages (from rich>=12->dvc) (2.19.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in ./.venv/lib/python3.12/site-packages (from ruamel.yaml>=0.17.11->dvc) (0.2.15)
# Requirement already satisfied: pygit2>=1.14.0 in ./.venv/lib/python3.12/site-packages (from scmrepo<4,>=3.5.2->dvc) (1.19.0)
# Requirement already satisfied: asyncssh<3,>=2.13.1 in ./.venv/lib/python3.12/site-packages (from scmrepo<4,>=3.5.2->dvc) (2.21.1)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.12/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.4)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.12/site-packages (from zc.lockfile>=1.2.1->dvc) (80.9.0)
# Requirement already satisfied: aiohttp in ./.venv/lib/python3.12/site-packages (from aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (3.13.2)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (2.23)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in ./.venv/lib/python3.12/site-packages (from click-repl>=0.2.0->celery->dvc) (3.0.52)
# Requirement already satisfied: google-auth~=2.0 in ./.venv/lib/python3.12/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (2.43.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in ./.venv/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.6.0->mlflow) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./.venv/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.6.0->mlflow) (0.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.6.0->mlflow) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12->dvc) (0.1.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.6.0->mlflow) (0.59b0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (0.4.2)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.12/site-packages (from typer>=0.4.1->gto<2,>=1.6.0->dvc) (1.5.4)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.12/site-packages (from uvicorn<1->mlflow-skinny==3.6.0->mlflow) (0.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (4.9.1)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.12/site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery->dvc) (0.2.14)
# Requirement already satisfied: anyio<5,>=3.6.2 in ./.venv/lib/python3.12/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow) (4.12.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./.venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (0.6.1)

# %%
import pandas as pd
import os
from sklearn.datasets import load_iris

DATA_DIR="data"
DATA_RAW_DIR=os.path.join(DATA_DIR, "raw")
IRIS_PATH=os.path.join(DATA_RAW_DIR, "data.csv")
os.makedirs(DATA_DIR, exist_ok=True)
os.makedirs(DATA_RAW_DIR, exist_ok=True)
iris = load_iris()
data = pd.DataFrame(iris.data, columns=iris.feature_names)
data.to_csv(IRIS_PATH)
